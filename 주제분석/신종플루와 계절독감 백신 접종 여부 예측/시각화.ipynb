# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

label=['Mice','Knn','Hotdeck','Nafactor']
length=[0.6720,0.6281,0.6580,0.6839]

fig,axs=plt.subplots(figsize=(5,7))
plt.bar(label,length,color='#6397D6',alpha=0.5)
plt.xlabel('Dataset', fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.ylim(0,1)
plt.show()

# %%
label=['SMOTE X','SMOTE O']
length=[0.6839,0.7523]

fig,axs=plt.subplots(figsize=(5,7))
plt.bar(label,length,color='#E892C4',alpha=0.5)
plt.xlabel('SMOTE', fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.ylim(0,1)
plt.show()
